# %% [markdown]
# # Ethan DeMelo
# ## Homework 2
# ### Jupyter Notebook - Code and Markdown
#
# <p>
# Instructions:
# Find 2 different data sets and compute summary statistics.
#
# For each data set try to answer the following questions:
# <ol>
# <li>Data description and course.
# <li>What are the attribute/independant variable name?
# <li>If you have a target/dependant variable, what is it?
# <li>How many columns are there?
# <li>How many rows are there?
# <li>Are the columns numerical, categorical, or both?
# <li>Are there columns that provide no information? Just constant or unique values for all observations.
# <li>For each categorical columns compute the mode.
# <li>For each numerical column compute the mean (average), max, and min values.
# <li>Plot histograms for numerical columns -- comment on the distribution (normal, multi-modal etc)
# <li>Plot bar plots for categorical columns. -- comment on whether the data set is balanced in terms of the representation of the various labels in the categorical columns.
# </p>

# %% [markdown]
# ## Data Set 1
# ### Candy Data
# <p>
# This data set is about different candy types and some information about each
# </p>
# <p>
# Data set questions
# <ol>
# <li>This data set is about different candy types and some of their properties including ingredients and attributes
# <li>The independent variable name is the "competitorname" column
# <li>There are multiple dependent variables including Chocolate, fruity, caramel, peanutyalmondy, nougat, and others
# <li>There are 13 columns
# <li>There are 85 rows including the header row
# <li>The columns are categorical
# <li>There are no empty columns. There are constant values for some columns, and there are unique vvalues for some of the other columns
# </ol>
# </p>

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/IndraniMandal/ds-assets/main/assets/candy-data.csv"
candyData = pd.read_csv(url)
candyData
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# ..                         ...        ...     ...      ...             ...
# 80                   Twizzlers          0       1        0               0
# 81                    Warheads          0       1        0               0
# 82        WelchÕs Fruit Snacks          0       1        0               0
# 83  WertherÕs Original Caramel          0       0        1               0
# 84                    Whoppers          1       0        0               0
#
# ...

# %% [markdown]
# <ol start="8">
# <li> Categorical Column Modes

# %% [markdown]
# <ol>

# %%
candyData.competitorname.mode()
# Out:
# 0                      100 Grand
# 1                   3 Musketeers
# 2                      Air Heads
# 3                     Almond Joy
# 4                      Baby Ruth
#                  ...
# 80                     Twizzlers
# 81                      Warheads
# 82          WelchÕs Fruit Snacks
# 83    WertherÕs Original Caramel
# 84                      Whoppers
# Name: competitorname, Length: 85, dtype: object

# %% [markdown]
# <ol start="9">
# <li> Numerical Column mean, max, and min

# %%
candyData.sugarpercent.mean()
# Out:
# 0.4786470514588235

# %%
candyData.sugarpercent.max()
# Out:
# 0.98799998

# %%
candyData.sugarpercent.min()
# Out:
# 0.011

# %%
candyData.pricepercent.mean()
# Out:
# 0.46888235249411764

# %%
candyData.pricepercent.max()
# Out:
# 0.97600001

# %%
candyData.pricepercent.min()
# Out:
# 0.011

# %%
candyData.winpercent.mean()
# Out:
# 50.316763811764716

# %%
candyData.winpercent.max()
# Out:
# 84.18029

# %%
candyData.winpercent.min()
# Out:
# 22.445341

# %% [markdown]
# <ol start="10">
# <li>Numerical column histograms

# %%
numerical_columns = ['sugarpercent', 'pricepercent', 'winpercent']
candyData[numerical_columns].hist()
# Out:
# array([[<Axes: title={'center': 'sugarpercent'}>,
#         <Axes: title={'center': 'pricepercent'}>],
#        [<Axes: title={'center': 'winpercent'}>, <Axes: >]], dtype=object)

# %% [markdown]
# <p>
# SugarPercent and PricePercent are multi-modal<br>
# Winpercent is pretty much normally distributed
# </p>
#
# <p>
# <ol start = "11">
# <li> Bar plots for categorical columns
# </ol>

# %%
import matplotlib.pyplot as plot
categorical_columns = ["competitorname"]
candyData[categorical_columns].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='competitorname'>

# %% [markdown]
# The data set is balanced in terms of the representation of the various labels in the competitorname column

# %% [markdown]
# ## Data Set 1
# ### Covid Summary
#
# <p>
# Data set questions
# <ol>
# <li>This data set is about different countries and their covid information including information about the total number of confirmed cases, deaths, recoveries, active cases, and other attributes
# <li>The independent variable name is the "country" column
# <li>There are multiple dependent variables including continent, total_confirmed, total_deaths, total_recovered, active cases, and others
# <li>There are 12 columns
# <li>There are 226 rows including the header row
# <li>The columns are both categorical and numerical
# <li>There are some empty columns. There are no constant values for any of the columns
# </ol>
# </p>

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/IndraniMandal/ds-assets/main/assets/worldometer_coronavirus_summary_data.csv"
covidData = pd.read_csv(url)
covidData
# Out:
#                        country          continent  total_confirmed  \
# 0                  Afghanistan               Asia           179267
# 1                      Albania             Europe           275574
# 2                      Algeria             Africa           265816
# 3                      Andorra             Europe            42156
# 4                       Angola             Africa            99194
# ..                         ...                ...              ...
# 221  Wallis And Futuna Islands  Australia/Oceania              454
# 222             Western Sahara             Africa               10
# 223                      Yemen               Asia            11819
# 224                     Zambia             Africa           320591
# 225                   Zimbabwe             Africa           249206
#
#      total_deaths  total_recovered  active_cases  serious_or_critical  \
# 0          7690.0         162202.0        9375.0               1124.0
# ...

# %% [markdown]
# <ol start="8">
# <li>Categorical columns modes
# </ol>

# %%
covidData.country.mode()
# Out:
# 0                    Afghanistan
# 1                        Albania
# 2                        Algeria
# 3                        Andorra
# 4                         Angola
#                  ...
# 221    Wallis And Futuna Islands
# 222               Western Sahara
# 223                        Yemen
# 224                       Zambia
# 225                     Zimbabwe
# Name: country, Length: 226, dtype: object

# %% [markdown]
# <ol start="9">
# <li> Numerical Column mean, max, and min

# %%
covidData.total_confirmed.mean()
# Out:
# 2305651.115044248

# %%
covidData.total_confirmed.max()
# Out:
# 84209473

# %%
covidData.total_confirmed.min()
# Out:
# 2

# %%
covidData.total_deaths.mean()
# Out:
# 28844.41743119266

# %%
covidData.total_deaths.max()
# Out:
# 1026646.0

# %%
covidData.total_deaths.min()
# Out:
# 1.0

# %%
covidData.total_recovered.mean()
# Out:
# 2256851.1421568627

# %%
covidData.total_recovered.max()
# Out:
# 81244260.0

# %%
covidData.total_recovered.min()
# Out:
# 1.0

# %%
covidData.active_cases.mean()
# Out:
# 68610.29411764706

# %%
covidData.active_cases.max()
# Out:
# 1938567.0

# %%
covidData.active_cases.min()
# Out:
# 0.0

# %%
covidData.serious_or_critical.mean()
# Out:
# 269.48275862068965

# %%
covidData.serious_or_critical.max()
# Out:
# 8318.0

# %%
covidData.serious_or_critical.min()
# Out:
# 1.0

# %% [markdown]
# <ol start="10">
# <li> Histograms for numerical columns

# %%
numerical_columns = ['total_confirmed', 'total_deaths', 'total_recovered', 'active_cases', 'serious_or_critical']
covidData[numerical_columns].hist()
# Out:
# array([[<Axes: title={'center': 'total_confirmed'}>,
#         <Axes: title={'center': 'total_deaths'}>],
#        [<Axes: title={'center': 'total_recovered'}>,
#         <Axes: title={'center': 'active_cases'}>],
#        [<Axes: title={'center': 'serious_or_critical'}>, <Axes: >]],
#       dtype=object)

# %% [markdown]
# <p>
# All columns have normal distribution types
# </p>
#
# <ol start="11">
# <li>Bar plots for categorical columns

# %%
import matplotlib.pyplot as plot
categorical_columns = ["country"]
covidData[categorical_columns].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# The data set is balanced in terms of the representation of the various labels in the country column.
